# %% [markdown]
# ## Import Modules

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
cat_col = []
for x in df.dtypes.index:
    if df.dtypes[x] == 'object':
        cat_col.append(x)
cat_col
# Out:
# ['Name',
#  'Photo',
#  'Nationality',
#  'Flag',
#  'Club',
#  'Club Logo',
#  'Value',
#  'Wage',
#  'Preferred Foot',
#  'Work Rate',
#  'Body Type',
#  'Real Face',
#  'Position',
#  'Joined',
#  'Loaned From',
#  'Contract Valid Until',
#  'Height',
#  'Weight',
#  'LS',
#  'ST',
#  'RS',
#  'LW',
#  'LF',
#  'CF',
#  'RF',
#  'RW',
#  'LAM',
#  'CAM',
#  'RAM',
#  'LM',
#  'LCM',
#  'CM',
#  'RCM',
#  'RM',
#  'LWB',
#  'LDM',
#  'CDM',
#  'RDM',
#  'RWB',
#  'LB',
#  'LCB',
#  'CB',
#  'RCB',
#  'RB',
#  'Release Clause']

# %%
for x in cat_col:
    print(x)
    print(df[x].value_counts())
    print()
# Out:
# Name
# J. Rodríguez    11
# Paulinho         8
# R. Williams      7
# J. Williams      7
# J. Hernández     6
#                 ..
# G. Loiacono      1
# R. Gikiewicz     1
# S. Kobayashi     1
# E. Ersoy         1
# M. Born          1
# Name: Name, Length: 17194, dtype: int64
#
# Photo
# https://cdn.sofifa.org/players/4/19/215250.png    1
# https://cdn.sofifa.org/players/4/19/239942.png    1
# https://cdn.sofifa.org/players/4/19/199890.png    1
# https://cdn.sofifa.org/players/4/19/236406.png    1
# https://cdn.sofifa.org/players/4/19/243748.png    1
#                                                  ..
# https://cdn.sofifa.org/players/4/19/230459.png    1
# https://cdn.sofifa.org/players/4/19/237108.png    1
# https://cdn.sofifa.org/players/4/19/223736.png    1
# https://cdn.sofifa.org/players/4/19/242102.png    1
# https://cdn.sofifa.org/players/4/19/242221.png    1
# Name: Photo, Length: 18207, dtype: int64
#
# Nationality
# England      1662
# Germany      1198
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %% [markdown]
# ## Preprocessing the dataset

# %%
df.drop(columns = ['Unnamed: 0', 'Photo', 'Flag', 'Club Logo', 'Nationality', 'Club', 'Joined', 'Loaned From', 'Contract Valid Until'], inplace = True)

# %% [markdown]
# #### Value

# %%
## Changing value
for i,x in enumerate(df['Value']):
    if x[-1]=='M':
        df['Value'][i] = float(x[1:-1])*1000000
    elif x[-1] == 'K':
        df['Value'][i] = float(x[1:-1])*1000

# %%
df['Value'].value_counts()
# Out:
# 1100000.0      431
# 375000.0       372
# 425000.0       354
# 325000.0       351
# 450000.0       343
#               ...
# 51500000.0       1
# 93000000.0       1
# 102000000.0      1
# 44500000.0       1
# 64000000.0       1
# Name: Value, Length: 217, dtype: int64

# %%
set(df['Value'])
# Out:
# {10000.0,
#  100000.0,
#  1000000.0,
#  10000000.0,
#  102000000.0,
#  10500000.0,
#  110000.0,
#  1100000.0,
#  11000000.0,
#  110500000.0,
#  11500000.0,
#  118500000.0,
#  120000.0,
#  1200000.0,
#  12000000.0,
#  12500000.0,
#  130000.0,
#  1300000.0,
#  13000000.0,
#  13500000.0,
#  140000.0,
#  1400000.0,
#  14000000.0,
#  14500000.0,
#  150000.0,
#  1500000.0,
#  15000000.0,
#  15500000.0,
#  160000.0,
#  1600000.0,
#  16000000.0,
#  16500000.0,
#  170000.0,
#  1700000.0,
#  17000000.0,
#  17500000.0,
#  180000.0,
#  1800000.0,
#  18000000.0,
#  18500000.0,
#  190000.0,
#  1900000.0,
#  19000000.0,
#  19500000.0,
#  20000.0,
#  200000.0,
#  2000000.0,
#  20000000.0,
#  20500000.0,
#  210000.0,
#  2100000.0,
#  21000000.0,
#  21500000.0,
#  220000.0,
#  2200000.0,
#  22000000.0,
#  22500000.0,
#  230000.0,
#  2300000.0,
#  23000000.0,
#  23500000.0,
#  240000.0,
#  2400000.0,
#  24000000.0,
#  24500000.0,
#  250000.0,
#  2500000.0,
#  25000000.0,
#  25500000.0,
#  260000.0,
# ...

# %%
df.drop(df[df['Value']=='€0'].index, inplace=True)

# %%
df['Value'] = df['Value'].astype(float)

# %% [markdown]
# #### Wage

# %%
df['Wage'].isnull().sum()
# Out:
# 0

# %%
wage_list = []
for v in df['Wage']:
    wage_list.append(v)

# %%
print(set(wage_list))
# Out:
# {'€50K', '€78K', '€190K', '€96K', '€250K', '€68K', '€565K', '€21K', '€95K', '€26K', '€44K', '€3K', '€115K', '€200K', '€285K', '€255K', '€82K', '€340K', '€100K', '€210K', '€225K', '€265K', '€170K', '€150K', '€84K', '€110K', '€155K', '€38K', '€185K', '€18K', '€86K', '€85K', '€300K', '€59K', '€405K', '€8K', '€80K', '€245K', '€60K', '€91K', '€76K', '€90K', '€260K', '€73K', '€48K', '€215K', '€145K', '€53K', '€125K', '€28K', '€165K', '€66K', '€74K', '€31K', '€69K', '€42K', '€25K', '€65K', '€30K', '€4K', '€49K', '€89K', '€97K', '€14K', '€7K', '€39K', '€62K', '€99K', '€175K', '€205K', '€230K', '€180K', '€93K', '€455K', '€24K', '€41K', '€72K', '€43K', '€63K', '€1K', '€290K', '€51K', '€37K', '€79K', '€27K', '€67K', '€58K', '€380K', '€98K', '€71K', '€34K', '€54K', '€20K', '€105K', '€420K', '€56K', '€77K', '€23K', '€355K', '€10K', '€5K', '€140K', '€130K', '€75K', '€47K', '€11K', '€120K', '€32K', '€36K', '€13K', '€22K', '€87K', '€61K', '€46K', '€240K', '€52K', '€16K', '€235K', '€40K', '€45K', '€3
# ...

# %%
for i,x in enumerate(wage_list):
    if x[-1] == 'M':
        wage_list[i] = float(x[1:-1])*1000000
    elif x[-1] == 'K':
        wage_list[i] = float(str(x)[1:-1])*1000

# %%
print(set(wage_list))
# Out:
# {64000.0, 405000.0, 21000.0, 85000.0, 170000.0, 42000.0, 255000.0, 63000.0, 340000.0, 84000.0, 20000.0, 105000.0, 41000.0, 190000.0, 62000.0, 19000.0, 83000.0, 40000.0, 125000.0, 61000.0, 210000.0, 82000.0, 18000.0, 39000.0, 380000.0, 60000.0, 145000.0, 81000.0, 17000.0, 230000.0, 38000.0, 315000.0, 59000.0, 80000.0, 16000.0, 165000.0, 37000.0, 250000.0, 58000.0, 15000.0, 79000.0, 420000.0, 100000.0, 36000.0, 185000.0, 57000.0, 78000.0, 14000.0, 355000.0, 35000.0, 99000.0, 120000.0, 56000.0, 205000.0, 77000.0, 13000.0, 290000.0, 98000.0, 34000.0, 55000.0, 140000.0, 12000.0, 76000.0, 225000.0, 33000.0, 97000.0, 54000.0, 75000.0, 11000.0, 160000.0, 96000.0, 32000.0, 565000.0, 245000.0, 53000.0, 74000.0, 10000.0, 31000.0, 95000.0, 43000.0, 180000.0, 52000.0, 265000.0, 73000.0, 9000.0, 94000.0, 30000.0, 115000.0, 51000.0, 200000.0, 72000.0, 8000.0, 285000.0, 93000.0, 29000.0, 50000.0, 455000.0, 135000.0, 71000.0, 7000.0, 92000.0, 28000.0, 49000.0, 70000.0, 6000.0, 155000.0, 91000.0, 2700
# ...

# %%
df['Wage']=wage_list

# %%
df['Wage'] = df['Wage'].astype(int)

# %% [markdown]
# #### Body type

# %%
df['Body Type'].value_counts()
# Out:
# Normal                 10428
# Lean                    6349
# Stocky                  1123
# Shaqiri                    1
# Messi                      1
# C. Ronaldo                 1
# Akinfenwa                  1
# Neymar                     1
# Courtois                   1
# PLAYER_BODY_TYPE_25        1
# Name: Body Type, dtype: int64

# %%
##removing single body type values
df.drop(df[df['Body Type']=='Neymar'].index, inplace=True)
df.drop(df[df['Body Type']=='C. Ronaldo'].index, inplace=True)
df.drop(df[df['Body Type']=='Akinfenwa'].index, inplace=True)
df.drop(df[df['Body Type']=='Courtois'].index, inplace=True)
df.drop(df[df['Body Type']=='Messi'].index, inplace=True)
df.drop(df[df['Body Type']=='PLAYER_BODY_TYPE_25'].index, inplace=True)
df.drop(df[df['Body Type']=='Shaqiri'].index, inplace=True)
df['Body Type'].value_counts()
# Out:
# Normal    10428
# Lean       6349
# Stocky     1123
# Name: Body Type, dtype: int64

# %% [markdown]
# #### Height

# %%
df['Height'] = df['Height'].fillna('0\'0')

# %%
df['Height'].value_counts()
# Out:
# 6'0     2836
# 5'10    2448
# 5'9     2201
# 5'11    2131
# 6'2     1987
# 6'1     1885
# 6'3      975
# 5'8      933
# 5'7      890
# 6'4      739
# 5'6      311
# 6'5      241
# 5'5      144
# 6'6       90
# 0'0       48
# 5'4       30
# 6'7       21
# 5'3       18
# 6'8       10
# 5'2        5
# 5'1        3
# 6'9        2
# Name: Height, dtype: int64

# %%
##Height to cm
for i, height in enumerate(df['Height']):
    ft, inch = map(int, str(height).split('\''))
    totalInch = (ft*12)+inch
    totalHeightInCm = int(float(totalInch)*2.54)
    df['Height'][i]=totalHeightInCm

# %%
height_list = []
for i, height in enumerate(df['Height']):
    height_list.append(height)

for i, height in enumerate(height_list):
    if not str(height).isdigit():
        ft, inch = map(int, str(height).split('\''))
        totalInch = (ft*12)+inch
        totalHeightInCm = int(float(totalInch)*2.54)
        height_list[i]=totalHeightInCm

# %%
import copy
new_height_list = copy.deepcopy(height_list)

# %%
new_height_list = list(filter(lambda a: a != 0, new_height_list))
set(new_height_list)
# Out:
# {154,
#  157,
#  160,
#  162,
#  165,
#  167,
#  170,
#  172,
#  175,
#  177,
#  180,
#  182,
#  185,
#  187,
#  190,
#  193,
#  195,
#  198,
#  200,
#  203,
#  205}

# %%
height_mean = (np.mean(new_height_list))

# %%
for idx, item in enumerate(height_list):
    if item == 0:
        height_list[idx] = height_mean

# %%
for i,v in enumerate(height_list):
    height_list[i]=int(v)

# %%
df['Height'] = height_list

# %%
df['Height'] = df['Height'].astype(int)

# %% [markdown]
# #### Weight

# %%
df['Weight'] = df['Weight'].fillna('0lbs')

# %%
weights_list = []
for x in df['Weight']:
    weights_list.append(x)
print(set(weights_list))
# Out:
# {'146lbs', '212lbs', '220lbs', '143lbs', '119lbs', '187lbs', '132lbs', '218lbs', '170lbs', '0lbs', '150lbs', '126lbs', '190lbs', '134lbs', '161lbs', '128lbs', '174lbs', '121lbs', '148lbs', '154lbs', '203lbs', '179lbs', '110lbs', '137lbs', '141lbs', '214lbs', '183lbs', '163lbs', '229lbs', '117lbs', '176lbs', '157lbs', '223lbs', '192lbs', '185lbs', '181lbs', '172lbs', '201lbs', '216lbs', '168lbs', '194lbs', '225lbs', '207lbs', '123lbs', '227lbs', '159lbs', '209lbs', '165lbs', '139lbs', '205lbs', '196lbs', '115lbs', '152lbs', '236lbs', '234lbs', '198lbs', '130lbs'}

# %%
for i, weight in enumerate(weights_list):
    weights_list[i]=weight.replace('lbs','')

# %%
print(set(weights_list))
# Out:
# {'205', '216', '196', '185', '209', '137', '134', '117', '154', '198', '212', '190', '207', '179', '187', '115', '146', '225', '163', '194', '130', '132', '157', '159', '201', '181', '192', '172', '123', '150', '183', '234', '161', '119', '148', '223', '214', '170', '121', '141', '220', '176', '203', '110', '168', '236', '0', '174', '229', '152', '143', '165', '227', '128', '126', '218', '139'}

# %%
for i, v in enumerate(weights_list):
    weights_list[i]=int(v)

# %%
new_weight_list = copy.deepcopy(weights_list)
new_weight_list = list(filter(lambda a: a != 0, new_weight_list))
weight_mean = (np.mean(new_weight_list))
for idx, item in enumerate(weights_list):
    if item == 0:
        weights_list[idx] = weight_mean

# %%
print(set(weights_list))
# Out:
# {128, 130, 132, 134, 137, 139, 141, 143, 146, 148, 150, 152, 154, 157, 159, 161, 163, 165, 165.95865921787708, 168, 170, 172, 174, 176, 179, 181, 183, 185, 187, 190, 192, 194, 196, 198, 201, 203, 205, 207, 209, 212, 214, 216, 218, 220, 223, 225, 227, 229, 234, 236, 110, 115, 117, 119, 121, 123, 126}

# %%
df['Weight']=weights_list

# %%
df['Weight'] = df['Weight'].astype(int)

# %% [markdown]
# #### Release Caluse

# %%
df['Release Clause'].isnull().sum()
# Out:
# 1312

# %%
df['Release Clause'].fillna('€0', inplace = True)

# %%
df['Release Clause'].isnull().sum()
# Out:
# 0

# %%
release_list = []
for x in df['Release Clause']:
    release_list.append(x)
print(set(release_list))
# Out:
# {'€975K', '€570K', '€457K', '€242K', '€605K', '€332K', '€356K', '€125.1M', '€30.4M', '€259K', '€11.2M', '€969K', '€84K', '€289K', '€156K', '€860K', '€494K', '€148K', '€219K', '€176K', '€34.5M', '€928K', '€394K', '€188K', '€26.7M', '€402K', '€16.4M', '€699K', '€666K', '€670K', '€906K', '€215K', '€566K', '€62.6M', '€5M', '€1.3M', '€125K', '€74K', '€360K', '€57.4M', '€556K', '€984K', '€84.1M', '€62K', '€391K', '€34.6M', '€451K', '€365K', '€763K', '€50.6M', '€12.9M', '€24.6M', '€5.5M', '€447K', '€32.6M', '€616K', '€580K', '€682K', '€808K', '€2.3M', '€325K', '€53.3M', '€25.5M', '€467K', '€8.5M', '€254K', '€532K', '€679K', '€47.5M', '€235K', '€805K', '€40K', '€441K', '€32.2M', '€83K', '€11.1M', '€610K', '€164M', '€689K', '€224K', '€533K', '€223K', '€131K', '€50K', '€51M', '€66.4M', '€501K', '€9.8M', '€522K', '€172K', '€137.4M', '€173K', '€329K', '€30.8M', '€657K', '€926K', '€33M', '€576K', '€239K', '€508K', '€212K', '€477K', '€191K', '€27.2M', '€435K', '€750K', '€90K', '€520K', '€17M', '€1
# ...

# %%
for i,x in enumerate(release_list):
    if x[-1]=='M':
        release_list[i] = float(x[1:-1])*1000000
    elif x[-1] == 'K':
        release_list[i] = float(x[1:-1])*1000

# %%
print(set(release_list))
# Out:
# {25600000.0, 213000.0, 426000.0, 639000.0, 28500000.0, 2900000.0, 41000.0, 254000.0, 467000.0, 31400000.0, 5800000.0, 680000.0, 893000.0, 295000.0, 8700000.0, 508000.0, 934000.0, 123000.0, 88400000.0, 11600000.0, 336000.0, 762000.0, 975000.0, 14500000.0, 164000.0, 377000.0, 17400000.0, 418000.0, 631000.0, 844000.0, 33000.0, 459000.0, 74000.0, 26100000.0, 500000.0, 713000.0, 926000.0, 54600000.0, 3400000.0, 328000.0, 754000.0, 967000.0, 6300000.0, 156000.0, 369000.0, 582000.0, 795000.0, 60400000.0, 34800000.0, 9200000.0, 410000.0, 623000.0, 114500000.0, 88900000.0, 12100000.0, 25000.0, 238000.0, 451000.0, 15000000.0, 664000.0, 877000.0, 66000.0, 279000.0, 17900000.0, 43500000.0, 120300000.0, 705000.0, 918000.0, 320000.0, 123200000.0, 46400000.0, 20800000.0, 533000.0, 959000.0, 74900000.0, 23700000.0, 148000.0, 361000.0, 574000.0, 52200000.0, 26600000.0, 1000000.0, 189000.0, 402000.0, 828000.0, 106300000.0, 29500000.0, 55100000.0, 3900000.0, 17000.0, 230000.0, 32400000.0, 58000000.0, 6
# ...

# %%
for i,v in enumerate(release_list):
    if v=='€0':
        release_list[i]=0

# %%
new_release_list = copy.deepcopy(release_list)
new_release_list = list(filter(lambda a: a != 0, new_release_list))
release_mean = (np.mean(new_release_list))
for idx, item in enumerate(release_list):
    if item == 0:
        release_list[idx] = release_mean

# %%
for i, v in enumerate(release_list):
    release_list[i]=int(v)

# %%
print(set(release_list))
# Out:
# {25600000, 213000, 426000, 639000, 28500000, 2900000, 41000, 254000, 467000, 31400000, 5800000, 680000, 893000, 295000, 8700000, 508000, 934000, 123000, 88400000, 11600000, 336000, 762000, 975000, 14500000, 164000, 377000, 17400000, 418000, 631000, 844000, 33000, 459000, 74000, 26100000, 500000, 713000, 926000, 54600000, 3400000, 328000, 754000, 967000, 6300000, 156000, 369000, 582000, 795000, 60400000, 34800000, 9200000, 410000, 623000, 114500000, 88900000, 12100000, 25000, 238000, 451000, 15000000, 664000, 877000, 66000, 279000, 17900000, 43500000, 120300000, 705000, 918000, 320000, 123200000, 46400000, 20800000, 533000, 959000, 74900000, 23700000, 148000, 361000, 574000, 52200000, 26600000, 1000000, 189000, 402000, 828000, 106300000, 29500000, 55100000, 3900000, 17000, 230000, 32400000, 58000000, 6800000, 656000, 58000, 112100000, 60900000, 9700000, 35300000, 910000, 99000, 63800000, 38200000, 12600000, 312000, 525000, 738000, 15500000, 140000, 353000, 566000, 779000, 69600000, 18
# ...

# %%
df['Release Clause']=release_list

# %%
df['Release Clause'] = df['Release Clause'].astype(int)

# %%
df.describe()
# Out:
#                   ID           Age       Overall     Potential         Value  \
# count   17948.000000  17948.000000  17948.000000  17948.000000  1.794800e+04
# mean   214327.065411     25.093771     66.220415     71.317194  2.420510e+06
# std     29846.075938      4.659374      6.908592      6.130212  5.435954e+06
# min        16.000000     16.000000     46.000000     48.000000  1.000000e+04
# 25%    200301.000000     21.000000     62.000000     67.000000  3.250000e+05
# 50%    221745.000000     25.000000     66.000000     71.000000  7.000000e+05
# 75%    236536.250000     28.000000     71.000000     75.000000  2.000000e+06
# max    246620.000000     45.000000     91.000000     95.000000  1.020000e+08
#
#                 Wage       Special  International Reputation     Weak Foot  \
# count   17948.000000  17948.000000              17900.000000  17900.000000
# mean     9764.542010   1598.011032                  1.112682      2.947095
# ...

# %%
df.head()
# Out:
#        ID          Name  Age  Overall  Potential        Value    Wage  \
# 3  193080        De Gea   27       91         93   72000000.0  260000
# 4  192985  K. De Bruyne   27       91         92  102000000.0  355000
# 5  183277     E. Hazard   27       91         91   93000000.0  340000
# 6  177003     L. Modrić   32       91         91   67000000.0  420000
# 7  176580     L. Suárez   31       91         91   80000000.0  455000
#
#    Special Preferred Foot  International Reputation  ...  Marking  \
# 3     1471          Right                       4.0  ...     15.0
# 4     2281          Right                       4.0  ...     68.0
# 5     2142          Right                       4.0  ...     34.0
# 6     2280          Right                       4.0  ...     60.0
# 7     2346          Right                       5.0  ...     62.0
#
#    StandingTackle SlidingTackle GKDiving GKHandling GKKicking  GKPositioning  \
# ...

# %%
x = df.isnull().sum()
for i in x:
    print(i)
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 0
# 0
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 2036
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 0
# 0

# %%
clean_df = copy.deepcopy(df)

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#                   ID           Age       Overall     Potential         Value  \
# count   15912.000000  15912.000000  15912.000000  15912.000000  15912.000000
# mean   215090.151081     24.981838     66.439228     71.518414     13.702550
# std     28472.541098      4.540627      6.797137      6.073258      1.372837
# min        16.000000     16.000000     46.000000     48.000000      9.210440
# 25%    200876.750000     21.000000     62.000000     67.000000     12.765691
# 50%    221983.500000     25.000000     66.000000     71.000000     13.527830
# 75%    236632.500000     28.000000     71.000000     75.000000     14.603968
# max    246620.000000     39.000000     91.000000     95.000000     18.440483
#
#                Wage       Special  International Reputation     Weak Foot  \
# count  15912.000000  15912.000000              15912.000000  15912.000000
# mean       8.322277   1667.121418                  1.114819      3.003771
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15912 entries, 4 to 18206
# Data columns (total 80 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        15912 non-null  int64
#  1   Name                      15912 non-null  object
#  2   Age                       15912 non-null  int64
#  3   Overall                   15912 non-null  int64
#  4   Potential                 15912 non-null  int64
#  5   Value                     15912 non-null  float64
#  6   Wage                      15912 non-null  float64
#  7   Special                   15912 non-null  int64
#  8   Preferred Foot            15912 non-null  object
#  9   International Reputation  15912 non-null  float64
#  10  Weak Foot                 15912 non-null  float64
#  11  Skill Moves               15912 non-null  float64
#  12  Work Rate                 15912 non-null  object
# ...

# %% [markdown]
# ## Exploratory data analysis

# %%
sns.distplot(df['Overall'])
# Out:
# <AxesSubplot:xlabel='Overall', ylabel='Density'>

# %%
sns.distplot(df['Value'])
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Density'>

# %%
df['Value'] = np.log(1+df['Value'])

# %%
sns.distplot(df['Value'])
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Density'>

# %%
sns.distplot(df['Wage'])
# Out:
# <AxesSubplot:xlabel='Wage', ylabel='Density'>

# %%
df['Wage'] = np.log(1+df['Wage'])
sns.distplot(df['Wage'])
# Out:
# <AxesSubplot:xlabel='Wage', ylabel='Density'>

# %%
sns.distplot(df['Release Clause'])
# Out:
# <AxesSubplot:xlabel='Release Clause', ylabel='Density'>

# %%
df['Release Clause'] = np.log(1+df['Release Clause'])
sns.distplot(df['Release Clause'])
# Out:
# <AxesSubplot:xlabel='Release Clause', ylabel='Density'>

# %%
sns.countplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(df['Preferred Foot'])
# Out:
# <AxesSubplot:xlabel='Preferred Foot', ylabel='count'>

# %%
sns.countplot(df['Body Type'])
# Out:
# <AxesSubplot:xlabel='Body Type', ylabel='count'>

# %%
# plt.figure(figsize=(15,5))
l = list(df['Position'].unique())
chart = sns.countplot(df["Position"])
chart.set_xticklabels(labels=l, rotation=90)
# Out:
# [Text(0, 0, 'RCM'),
#  Text(1, 0, 'LF'),
#  Text(2, 0, 'RS'),
#  Text(3, 0, 'RCB'),
#  Text(4, 0, 'ST'),
#  Text(5, 0, 'LCM'),
#  Text(6, 0, 'CB'),
#  Text(7, 0, 'LDM'),
#  Text(8, 0, 'CAM'),
#  Text(9, 0, 'CDM'),
#  Text(10, 0, 'LS'),
#  Text(11, 0, 'LCB'),
#  Text(12, 0, 'RM'),
#  Text(13, 0, 'LAM'),
#  Text(14, 0, 'LW'),
#  Text(15, 0, 'LM'),
#  Text(16, 0, 'LB'),
#  Text(17, 0, 'RDM'),
#  Text(18, 0, 'RF'),
#  Text(19, 0, 'RW'),
#  Text(20, 0, 'CM'),
#  Text(21, 0, 'RB'),
#  Text(22, 0, 'RAM'),
#  Text(23, 0, 'CF'),
#  Text(24, 0, 'RWB'),
#  Text(25, 0, 'LWB')]

# %%
sns.countplot(df['Real Face'])
# Out:
# <AxesSubplot:xlabel='Real Face', ylabel='count'>

# %% [markdown]
# ## Correlation Matrix

# %%
corr = df.corr()
plt.figure(figsize=(100, 100))
sns.heatmap(corr, annot=True, cmap='coolwarm', annot_kws={'size': 20})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Onehot Encoding

# %%
cat_col = []
for x in df.dtypes.index:
    if df.dtypes[x] == 'object':
        cat_col.append(x)
print(cat_col)
# Out:
# ['Name', 'Preferred Foot', 'Work Rate', 'Body Type', 'Real Face', 'Position', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB']

# %%
df = pd.get_dummies(df, columns=['Preferred Foot', 'Work Rate', 'Body Type', 'Real Face', 'Position', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB'])
df.head()
# Out:
#        ID          Name  Age  Overall  Potential      Value       Wage  \
# 4  192985  K. De Bruyne   27       91         92  18.440483  12.779876
# 5  183277     E. Hazard   27       91         91  18.348110  12.736704
# 6  177003     L. Modrić   32       91         91  18.020203  12.948012
# 7  176580     L. Suárez   31       91         91  18.197537  13.028055
# 8  155862  Sergio Ramos   32       91         91  17.747336  12.847929
#
#    Special  International Reputation  Weak Foot  ...  RB_79+2  RB_79+3  \
# 4     2281                       4.0        5.0  ...        0        0
# 5     2142                       4.0        4.0  ...        0        0
# 6     2280                       4.0        4.0  ...        0        1
# 7     2346                       5.0        4.0  ...        0        0
# 8     2201                       4.0        3.0  ...        0        0
#
#    RB_80+2  RB_80+3  RB_81+2  RB_81+3  RB_82+2  RB_82+3  RB_83+3  RB_84+3
# ...

# %%
print(df.columns)
# Out:
# Index(['ID', 'Name', 'Age', 'Overall', 'Potential', 'Value', 'Wage', 'Special',
#        'International Reputation', 'Weak Foot',
#        ...
#        'RB_79+2', 'RB_79+3', 'RB_80+2', 'RB_80+3', 'RB_81+2', 'RB_81+3',
#        'RB_82+2', 'RB_82+3', 'RB_83+3', 'RB_84+3'],
#       dtype='object', length=2647)

# %% [markdown]
# ## Input Split

# %%
from sklearn.model_selection import train_test_split


X = df.drop(columns = ['ID', 'Name', 'Jersey Number', 'Overall'])
y = df['Overall']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (12729, 2643)

# %% [markdown]
# ## Model Training

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
def train(model, X, y):
    # train the model
    model.fit(X, y)
    
    # predict the training set
    pred = model.predict(X)
    
    # perform cross-validation
    cv_score = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    cv_score = np.abs(np.mean(cv_score))
    
    print("Model Report")
    print("MSE:",mean_squared_error(y,pred))
    print("CV Score:", cv_score)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
model = LinearRegression(normalize=True)
train(model, X, y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
# Out:
# Model Report
# MSE: 0.48589854194867427
# CV Score: 6.855753621239951e+27
# <AxesSubplot:title={'center':'Model Coefficients'}>

# %%
model = Ridge(normalize=True)
train(model, X, y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
# Out:
# Model Report
# MSE: 2.283756092459769
# CV Score: 13.7516168913974
# <AxesSubplot:title={'center':'Model Coefficients'}>

# %%
model = Lasso()
train(model, X, y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
# Out:
# Model Report
# MSE: 3.794292207524081
# CV Score: 5.989989985554994
# <AxesSubplot:title={'center':'Model Coefficients'}>

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
train(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
# Out:
# Model Report
# MSE: 0.0
# CV Score: 12.767961058838466
# <AxesSubplot:title={'center':'Feature Importance'}>

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
train(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
# Out:
# Model Report
# MSE: 0.01682458521870286
# CV Score: 12.049925414478986
# <AxesSubplot:title={'center':'Feature Importance'}>

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
train(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")

# %%
from sklearn.linear_model import LogisticRegression
regressor = LogisticRegression()
regressor.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
print(regressor.intercept_)
# Out:
# [ 0.06034968  0.04724523  0.03811862  0.03108783  0.0243738   0.03386602
#   0.06922179  0.0496946   0.0477998   0.0462236   0.06424656  0.02428642
#   0.10501344  0.05755726  0.07059514  0.0252407   0.05000907  0.13081634
#   0.09660248  0.05942855  0.05710746  0.11885309  0.12917404  0.14920162
#   0.13430426  0.11651996  0.26415196  0.14987413  0.15924878  0.13270648
#   0.34421037  0.14087197  0.16459645  0.02950894  0.1291337   0.19258429
#   0.19759006  0.06523736  0.16867885  0.21056993  0.04901985  0.05857616
#  -0.05645245  0.00372    -0.0698281   0.00198924 -0.01431041 -0.03049836
#  -0.02277856 -0.02806791 -0.10997683 -0.12571715 -0.15465018 -0.11512348
#  -0.19399859 -0.16209181 -0.1653468  -0.15318325 -0.18107787 -0.21558491
#  -0.11666034 -0.15404213 -0.23425186 -0.10539718 -0.2673475  -0.20995287
#  -0.13210987 -0.12253101 -0.17026659 -0.14077    -0.07401119 -0.13435161
#  -0.05590053 -0.07755183 -0.1256678  -0.09607055 -0.0789335  -0.20470283]

# %%
y_pred = regressor.predict(X_test)

# %%
df_pred = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 11.545
# Mean Squared Error: 216.425
# Root Mean Squared Error: 14.711390145054274
